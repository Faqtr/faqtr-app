# %%
import pickle

# %%
dump = pickle.load(open('ml/gen_cnn_db/trainingpositive.p','r'))

# %%
text = open('ml/Statistical.txt', 'r').readlines()

# %%
text
# Out:
# ['Only one in 10 Americans possess a passport.\n',
#  'The recent financial crisis will push up to 100 million people in developing countries into absolute poverty.\n',
#  'There are 3 million Zimbabwean refugees in South Africa.\n',
#  "The size of India's middle class is 300 million people.\n",
#  'The 1998-2002 war in the DRC cost 5.4 million lives, more than any conflict since World War II. \n',
#  'Nine out of ten people we asked said they preferred it.\n',
#  'Statisticians have proven a clear correlation between Pona cream and smoother skin.\n',
#  'One out of every seven minutes spent online is on Facebook\n',
#  '340 million tweets are sent each and every day\n',
#  'Pinterest is the social network that skews most heavily towards female users, whilst Google+ is predominately used by men\n',
#  '300 million pictures are uploaded to Facebook every day via Instagram\n',
#  '61 percent of LinkedIn members use it as their primary professional networking site\n',
# ...

# %%
from ml.nlp.convert_to_question import convert_statement as cs

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/aditya/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
dictionary = dict()
for line in text:
    try:
        key, _ = cs(line.decode('utf-8', 'ignore'))
        print key, line
    except:
        pass
    dictionary.update({key.encode('utf-8', 'ignore'):line.decode('utf-8', 'ignore')})
# Out:
# How Many Much The recent financial crisis will push up to million people in developing countries into absolute poverty . The recent financial crisis will push up to 100 million people in developing countries into absolute poverty.
#
# How Many Much There are million Zimbabwean refugees in South Africa . There are 3 million Zimbabwean refugees in South Africa.
#
# How Many Much The size of India 's middle class is million people . The size of India's middle class is 300 million people.
#
# Statisticians have proven a clear correlation between Pona cream and smoother skin . Statisticians have proven a clear correlation between Pona cream and smoother skin.
#
# How Many Much million tweets are sent each and every day 340 million tweets are sent each and every day
#
# ...

# %%
count = 0
for line in dump:
    try:
        line[0] = dictionary[line[0].encode('utf-8', 'ignore')]
    except:
        count += 1
print count
# Out:
# 1205
